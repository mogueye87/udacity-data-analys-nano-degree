# %% [markdown]
# # Introduction to Data Analysis Process
# ## Breast Cancer Wisconsin (Diagnostic) Data Set
#
#
# ## Table of contents
# <ul>
#     <li><a href="#intro">Introduction</a></li>
#     <li><a href="#question">Question for dataset</a></li>
#     <li><a href="#wrang">Data Wrangling</a></li>
#     <li><a href="#gather">Gathering Data</a></li>
# </ul>

# %% [markdown]
# <a id="intro"></a>
# ## Introduction
# In this dataset, we will analyze breast cancer winsconsin dataset, we will analyze the dataset and predict whether the cancer is benign or malignant

# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.nunique()
# Out:
# id                         569
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave_points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave_points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# concave_points_worst       492
# ...

# %%
data.describe(include=['O'])
# Out:
#        diagnosis
# count        569
# unique         2
# top            B
# freq         357

# %%
columns = data.columns

# %%
print(columns)
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
# cleaning the dataset columns
cleaned_columns = []
def clean_columns(column_name):
    column_name = column_name.replace(' ','_')
    return column_name

# %%
for item in columns:
    cleaned_column = clean_columns(item)
    cleaned_columns.append(cleaned_column)

# %%
data.columns = cleaned_columns

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# <a id="question"><a/>
#
# ## Question for dataset
# Does the diagnosis (malignancy or bignancy) of a tumor  is related to it's texture?
# How would you go about answering these questions? Which parts of this dataset might you use for each one?
# * To answer this will focuses on the correlation between the tumor texture and it's diagnosis?
# * Plotting a scatter plot of the relation between the diagnosis and the texture?

# %% [markdown]
# <a id="wrang"></a>
# ## Data Wrangling
# Data wrangling in data analysis consist of the step of gathering, assessing and cleaning the data, while exploraty data analysis is related to the the exploration of the data for a better visualization.
# Data Gathering otherwise data acquisition the process of acquiring data from different sources (web, database,...)

# %%
# looking for null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave_points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
# looking for duplicate
sum(data.duplicated())
# Out:
# 0

# %%
# remove duplicated values 
data.drop_duplicates(inplace=True)

# %%
data.hist(figsize=(16,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B7A95D25C0>,
# ...
#       dtype=object)

# %%
# histo on a specific column
data.texture_mean.hist()

# %%
data.texture_mean.value_counts()
# Out:
# 14.93    3
# 15.70    3
# 18.90    3
# 16.84    3
# 17.46    3
# 18.22    3
# 20.52    3
# 16.85    3
# 19.83    3
# 18.89    2
# 13.98    2
# 20.22    2
# 18.18    2
# 18.61    2
# 21.25    2
# 27.15    2
# 21.84    2
# 14.96    2
# 16.58    2
# 20.76    2
# 21.53    2
# 15.51    2
# 21.46    2
# 21.59    2
# 13.90    2
# 17.12    2
# 16.62    2
# 21.54    2
# 19.04    2
# 20.74    2
#         ..
# 24.91    1
# 14.23    1
# 15.62    1
# 20.97    1
# 12.27    1
# 24.68    1
# 19.31    1
# 16.54    1
# 23.23    1
# 17.26    1
# 18.06    1
# 19.29    1
# 21.57    1
# 25.56    1
# 14.36    1
# 13.29    1
# 22.14    1
# 18.83    1
# 27.06    1
# 19.35    1
# 12.17    1
# 14.78    1
# 15.39    1
# 11.89    1
# 16.03    1
# 20.53    1
# 17.66    1
# 24.80    1
# 20.56    1
# 10.94    1
# Name: texture_mean, Length: 479, dtype: int64

# %%
# data.texture_mean.value_counts().plot(kind='bar')

# %%
# pd.plotting.scatter_matrix(data, figsize=(15,15))

# %%
data.plot(x='texture_mean', y = 'area_mean', kind="scatter")

# %%
data.plot(x='texture_mean', y = 'smoothness_mean', kind="scatter")

# %%
data.plot(x='texture_mean', y ='compactness_mean', kind="scatter")
